# %% [markdown]
# # EDLIF model
#
# Jaras I, Harada T, Orchard ME, Maldonado PE, Vergara RC. Extending the integrate-and-fire model to account for metabolic dependencies. Eur J Neurosci. 2021 Aug;54(4):5249-5260. doi: 10.1111/ejn.15326. Epub 2021 Jul 16. PMID: 34109698.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import nest
import numpy as np
import os

from pynestml.frontend.pynestml_frontend import generate_nest_target

NEST_SIMULATOR_INSTALL_LOCATION = nest.ll_api.sli_func("statusdict/prefix ::")
# Out:
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.3
#  Built: Mar 23 2022 13:33:55
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.

# %%
neuron_model = "edlif_percent_mwe.nestml"

generate_nest_target(input_path=neuron_model,
                     target_path="/tmp/nestml-component",
                     logging_level="INFO",
                     codegen_opts={"nest_path": NEST_SIMULATOR_INSTALL_LOCATION})
# Out:
# [1,GLOBAL, INFO]: List of files that will be processed:
# [2,GLOBAL, INFO]: /home/wis/Documents/nestml/ehp/edlif/edlif_percent_mwe.nestml
# [3,GLOBAL, INFO]: No module name specified; the generated module will be named "nestmlmodule"
# [4,GLOBAL, INFO]: Start processing '/home/wis/Documents/nestml/ehp/edlif/edlif_percent_mwe.nestml'!
# [6,edlif_percent_mwe, WARNING, [52:31;52:39]]: Non-matching unit types at pA +/- pA buffer! Implicitly replaced by pA +/- 1.0 * pA buffer.
# [7,edlif_percent_mwe, WARNING, [52:13;52:22]]: Non-matching unit types at mV / ms +/- pA / pF! Implicitly replaced by mV / ms +/- 1.0 * pA / pF.
# [8,edlif_percent_mwe, INFO, [21:15;21:15]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [9,edlif_percent_mwe, INFO, [24:15;24:15]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [10,edlif_percent_mwe, INFO, [25:15;25:15]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [11,edlif_percent_mwe, INFO, [72:17;72:17]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [12,edlif_percent_mwe, INFO, [77:17;77:17]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [13,edlif_percent_mwe, INFO, [78:16;78:16]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [14,edlif_percent_mwe, INFO, [79:16;79:16]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [15,edlif_percent_mwe, INFO, [80:16;80:16]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [16,edlif_percent_mwe, INFO, [81:21;81:21]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [17,edlif_percent_mwe, INFO, [82:21;82:21]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [18,edlif_percent_mwe, INFO, [84:17;84:17]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [19,edlif_percent_mwe, INFO, [85:17;85:17]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [20,edlif_percent_mwe, INFO, [86:17;86:17]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [21,edlif_percent_mwe, INFO, [114:30;114:30]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [22,edlif_percent_mwe, INFO, [116:30;116:30]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [23,edlif_percent_mwe, INFO, [125:17;125:17]]: Implicit casting from (compatible) type 'integer' to 'real'.
# Warning: PyGSL is not available. The stiffness test will be skipped.
# Warning: No module named 'pygsl'
#
#
# [24,GLOBAL, INFO]: Given template root path is not an absolute path. Creating the absolute path with default templates directory '/home/wis/anaconda3/envs/wnestml/lib/python3.10/site-packages/pynestml/codegeneration/resources_nest/point_neuron'
# [25,GLOBAL, INFO]: Given template root path is not an absolute path. Creating the absolute path with default templates directory '/home/wis/anaconda3/envs/wnestml/lib/python3.10/site-packages/pynestml/codegeneration/resources_nest/point_neuron'
# [26,GLOBAL, INFO]: The NEST installation was automatically detected as: /home/wis/anaconda3/envs/wnestml
# [27,GLOBAL, INFO]: Analysing/transforming neuron 'edlif_percent_mwe'
# [28,edlif_percent_mwe, INFO, [16:0;153:0]]: Starts processing of the model 'edlif_percent_mwe'
# INFO:Analysing input:
# INFO:{
#     "dynamics": [
#         {
#             "expression": "V_abs' = -V_abs / tau_m + ((I_kernel_exc__X__exc_spikes - I_kernel_inh__X__inh_spikes) + I_e + I_stim) / C_m",
#             "initial_values": {
#                 "V_abs": "0"
#             }
#         },
#         {
#             "expression": "ATP' = (((ATP_h - ATP) * K_ATP * homeostatic_s_enabled + ATP_basal) - ((ATP_basal + (E_ap_tr * E_ap / tau_ap / o_t) + ((ATP_kernel_exc__X__exc_spikes * E_syn_exc / tau_syn_atp_exc / w_max + ATP_kernel_inh__X__inh_spikes * E_syn_inh / tau_syn_atp_inh / w_min) / o_t / 1.0)))) * o_t",
#             "initial_values": {
#                 "ATP": "100"
#             }
#         },
#         {
#             "expression": "ATP_kernel_exc__X__exc_spikes = exp(-t / tau_syn_atp_exc)",
#             "initial_values": {}
#         },
#         {
#             "expression": "I_kernel_inh__X__inh_spikes = exp(-t / tau_syn_inh)",
#             "initial_values": {}
#         },
#         {
#             "expression": "I_kernel_exc__X__exc_spikes = exp(-t / tau_syn_exc)",
#             "initial_values": {}
#         },
#         {
#             "expression": "ATP_kernel_inh__X__inh_spikes = exp(-t / tau_syn_atp_inh)",
#             "initial_values": {}
#         }
#     ],
#     "options": {
#         "output_timestep_symbol": "__h"
#     },
#     "parameters": {
#         "ATP_basal": "E_rp + E_hk",
#         "ATP_h": "100",
#         "C_m": "250",
#         "E_L": "-70",
#         "E_ap": "15",
#         "E_hk": "5",
#         "E_rp": "5",
#         "E_syn_exc": "8",
#         "E_syn_inh": "5",
#         "I_e": "0",
#         "K_ATP": "1",
#         "V_reset": "-70 - E_L",
#         "V_th": "-55 - E_L",
#         "gamma": "16",
#         "o_t": "1 ** -1",
#         "t_ref": "5",
#         "tau_ap": "50",
#         "tau_m": "10",
#         "tau_syn_atp_exc": "20",
#         "tau_syn_atp_inh": "20",
#         "tau_syn_exc": "2",
#         "tau_syn_inh": "2",
#         "w_max": "1000",
#         "w_min": "1000"
#     }
# }
# INFO:Processing global options...
# INFO:Processing input shapes...
# INFO:
# Processing differential-equation form shape V_abs with defining expression = "-V_abs / tau_m + ((I_kernel_exc__X__exc_spikes - I_kernel_inh__X__inh_spikes) + I_e + I_stim) / C_m"
# INFO:	Returning shape: Shape "V_abs" of order 1
# INFO:Shape V_abs: reconstituting expression -V_abs/tau_m + I_e/C_m + (I_kernel_exc__X__exc_spikes - I_kernel_inh__X__inh_spikes + I_stim)/C_m
# INFO:
# Processing differential-equation form shape ATP with defining expression = "(((ATP_h - ATP) * K_ATP * homeostatic_s_enabled + ATP_basal) - ((ATP_basal + (E_ap_tr * E_ap / tau_ap / o_t) + ((ATP_kernel_exc__X__exc_spikes * E_syn_exc / tau_syn_atp_exc / w_max + ATP_kernel_inh__X__inh_spikes * E_syn_inh / tau_syn_atp_inh / w_min) / o_t / 1.0)))) * o_t"
# INFO:	Returning shape: Shape "ATP" of order 1
# INFO:Shape ATP: reconstituting expression -ATP*K_ATP*homeostatic_s_enabled*o_t + ATP_h*K_ATP*homeostatic_s_enabled*o_t - 1.0*ATP_kernel_exc__X__exc_spikes*E_syn_exc/(tau_syn_atp_exc*w_max) - 1.0*ATP_kernel_inh__X__inh_spikes*E_syn_inh/(tau_syn_atp_inh*w_min) - E_ap*E_ap_tr/tau_ap
# INFO:
# Processing function-of-time shape ATP_kernel_exc__X__exc_spikes with defining expression = "exp(-t/tau_syn_atp_exc)"
# INFO:Shape ATP_kernel_exc__X__exc_spikes: reconstituting expression -ATP_kernel_exc__X__exc_spikes/tau_syn_atp_exc
# INFO:
# Processing function-of-time shape I_kernel_inh__X__inh_spikes with defining expression = "exp(-t/tau_syn_inh)"
# INFO:Shape I_kernel_inh__X__inh_spikes: reconstituting expression -I_kernel_inh__X__inh_spikes/tau_syn_inh
# INFO:
# Processing function-of-time shape I_kernel_exc__X__exc_spikes with defining expression = "exp(-t/tau_syn_exc)"
# INFO:Shape I_kernel_exc__X__exc_spikes: reconstituting expression -I_kernel_exc__X__exc_spikes/tau_syn_exc
# INFO:
# Processing function-of-time shape ATP_kernel_inh__X__inh_spikes with defining expression = "exp(-t/tau_syn_atp_inh)"
# INFO:Shape ATP_kernel_inh__X__inh_spikes: reconstituting expression -ATP_kernel_inh__X__inh_spikes/tau_syn_atp_inh
# INFO:All known variables: [V_abs, ATP, ATP_kernel_exc__X__exc_spikes, I_kernel_inh__X__inh_spikes, I_kernel_exc__X__exc_spikes, ATP_kernel_inh__X__inh_spikes], all parameters used in ODEs: {K_ATP, E_syn_exc, tau_ap, tau_syn_inh, I_stim, C_m, w_min, ATP_h, tau_syn_atp_exc, tau_m, E_ap, o_t, homeostatic_s_enabled, I_e, w_max, E_syn_inh, tau_syn_exc, E_ap_tr, tau_syn_atp_inh}
# INFO:No numerical value specified for parameter "I_stim"
# INFO:No numerical value specified for parameter "homeostatic_s_enabled"
# INFO:No numerical value specified for parameter "E_ap_tr"
# INFO:
# Processing differential-equation form shape V_abs with defining expression = "-V_abs / tau_m + ((I_kernel_exc__X__exc_spikes - I_kernel_inh__X__inh_spikes) + I_e + I_stim) / C_m"
# INFO:	Returning shape: Shape "V_abs" of order 1
# INFO:
# Processing differential-equation form shape ATP with defining expression = "(((ATP_h - ATP) * K_ATP * homeostatic_s_enabled + ATP_basal) - ((ATP_basal + (E_ap_tr * E_ap / tau_ap / o_t) + ((ATP_kernel_exc__X__exc_spikes * E_syn_exc / tau_syn_atp_exc / w_max + ATP_kernel_inh__X__inh_spikes * E_syn_inh / tau_syn_atp_inh / w_min) / o_t / 1.0)))) * o_t"
# INFO:	Returning shape: Shape "ATP" of order 1
# INFO:
# Processing function-of-time shape ATP_kernel_exc__X__exc_spikes with defining expression = "exp(-t/tau_syn_atp_exc)"
# INFO:
# Processing function-of-time shape I_kernel_inh__X__inh_spikes with defining expression = "exp(-t/tau_syn_inh)"
# INFO:
# Processing function-of-time shape I_kernel_exc__X__exc_spikes with defining expression = "exp(-t/tau_syn_exc)"
# INFO:
# Processing function-of-time shape ATP_kernel_inh__X__inh_spikes with defining expression = "exp(-t/tau_syn_atp_inh)"
# INFO:Shape V_abs: reconstituting expression -V_abs/tau_m + (I_e + I_stim)/C_m + (I_kernel_exc__X__exc_spikes - I_kernel_inh__X__inh_spikes)/C_m
# INFO:Shape ATP: reconstituting expression -ATP*K_ATP*homeostatic_s_enabled*o_t + ATP_h*K_ATP*homeostatic_s_enabled*o_t - 1.0*ATP_kernel_exc__X__exc_spikes*E_syn_exc/(tau_syn_atp_exc*w_max) - 1.0*ATP_kernel_inh__X__inh_spikes*E_syn_inh/(tau_syn_atp_inh*w_min) - E_ap*E_ap_tr/tau_ap
# INFO:Shape ATP_kernel_exc__X__exc_spikes: reconstituting expression -ATP_kernel_exc__X__exc_spikes/tau_syn_atp_exc
# INFO:Shape I_kernel_inh__X__inh_spikes: reconstituting expression -I_kernel_inh__X__inh_spikes/tau_syn_inh
# INFO:Shape I_kernel_exc__X__exc_spikes: reconstituting expression -I_kernel_exc__X__exc_spikes/tau_syn_exc
# INFO:Shape ATP_kernel_inh__X__inh_spikes: reconstituting expression -ATP_kernel_inh__X__inh_spikes/tau_syn_atp_inh
# INFO:Dependency analysis...
# INFO:Shape V_abs: reconstituting expression -V_abs/tau_m + (I_e + I_stim)/C_m + (I_kernel_exc__X__exc_spikes - I_kernel_inh__X__inh_spikes)/C_m
# INFO:Shape ATP: reconstituting expression -ATP*K_ATP*homeostatic_s_enabled*o_t + ATP_h*K_ATP*homeostatic_s_enabled*o_t - 1.0*ATP_kernel_exc__X__exc_spikes*E_syn_exc/(tau_syn_atp_exc*w_max) - 1.0*ATP_kernel_inh__X__inh_spikes*E_syn_inh/(tau_syn_atp_inh*w_min) - E_ap*E_ap_tr/tau_ap
# INFO:Shape ATP_kernel_exc__X__exc_spikes: reconstituting expression -ATP_kernel_exc__X__exc_spikes/tau_syn_atp_exc
# INFO:Shape I_kernel_inh__X__inh_spikes: reconstituting expression -I_kernel_inh__X__inh_spikes/tau_syn_inh
# INFO:Shape I_kernel_exc__X__exc_spikes: reconstituting expression -I_kernel_exc__X__exc_spikes/tau_syn_exc
# INFO:Shape ATP_kernel_inh__X__inh_spikes: reconstituting expression -ATP_kernel_inh__X__inh_spikes/tau_syn_atp_inh
# INFO:Generating propagators for the following symbols: V_abs, ATP, ATP_kernel_exc__X__exc_spikes, I_kernel_inh__X__inh_spikes, I_kernel_exc__X__exc_spikes, ATP_kernel_inh__X__inh_spikes
# INFO:In ode-toolbox: returning outdict =
# INFO:[
#     {
#         "initial_values": {
#             "ATP": "100",
#             "ATP_kernel_exc__X__exc_spikes": "1",
#             "ATP_kernel_inh__X__inh_spikes": "1",
#             "I_kernel_exc__X__exc_spikes": "1",
#             "I_kernel_inh__X__inh_spikes": "1",
#             "V_abs": "0"
#         },
#         "parameters": {
#             "ATP_h": "100.000000000000",
#             "C_m": "250.000000000000",
#             "E_ap": "15.0000000000000",
#             "E_syn_exc": "8.00000000000000",
#             "E_syn_inh": "5.00000000000000",
#             "I_e": "0",
#             "K_ATP": "1.00000000000000",
#             "o_t": "1.00000000000000",
#             "tau_ap": "50.0000000000000",
#             "tau_m": "10.0000000000000",
#             "tau_syn_atp_exc": "20.0000000000000",
#             "tau_syn_atp_inh": "20.0000000000000",
#             "tau_syn_exc": "2.00000000000000",
#             "tau_syn_inh": "2.00000000000000",
#             "w_max": "1000.00000000000",
#             "w_min": "1000.00000000000"
#         },
#         "propagators": {
#             "__P__ATP__ATP": "1.0*exp(-K_ATP*__h*homeostatic_s_enabled*o_t)",
#             "__P__ATP__ATP_kernel_exc__X__exc_spikes": "1.0*E_syn_exc*(exp(__h/tau_syn_atp_exc) - exp(K_ATP*__h*homeostatic_s_enabled*o_t))*exp(-__h*(K_ATP*homeostatic_s_enabled*o_t + 1/tau_syn_atp_exc))/(w_max*(K_ATP*homeostatic_s_enabled*o_t*tau_syn_atp_exc - 1))",
#             "__P__ATP__ATP_kernel_inh__X__inh_spikes": "1.0*E_syn_inh*(exp(__h/tau_syn_atp_inh) - exp(K_ATP*__h*homeostatic_s_enabled*o_t))*exp(-__h*(K_ATP*homeostatic_s_enabled*o_t + 1/tau_syn_atp_inh))/(w_min*(K_ATP*homeostatic_s_enabled*o_t*tau_syn_atp_inh - 1))",
#             "__P__ATP_kernel_exc__X__exc_spikes__ATP_kernel_exc__X__exc_spikes": "1.0*exp(-__h/tau_syn_atp_exc)",
#             "__P__ATP_kernel_inh__X__inh_spikes__ATP_kernel_inh__X__inh_spikes": "1.0*exp(-__h/tau_syn_atp_inh)",
#             "__P__I_kernel_exc__X__exc_spikes__I_kernel_exc__X__exc_spikes": "1.0*exp(-__h/tau_syn_exc)",
#             "__P__I_kernel_inh__X__inh_spikes__I_kernel_inh__X__inh_spikes": "1.0*exp(-__h/tau_syn_inh)",
#             "__P__V_abs__I_kernel_exc__X__exc_spikes": "1.0*tau_m*tau_syn_exc*(-exp(__h/tau_m) + exp(__h/tau_syn_exc))*exp(-__h/tau_syn_exc - __h/tau_m)/(C_m*(tau_m - tau_syn_exc))",
#             "__P__V_abs__I_kernel_inh__X__inh_spikes": "1.0*tau_m*tau_syn_inh*(exp(__h/tau_m) - exp(__h/tau_syn_inh))*exp(-__h/tau_syn_inh - __h/tau_m)/(C_m*(tau_m - tau_syn_inh))",
#             "__P__V_abs__V_abs": "1.0*exp(-__h/tau_m)"
#         },
#         "solver": "analytical",
#         "state_variables": [
#             "V_abs",
#             "ATP",
#             "ATP_kernel_exc__X__exc_spikes",
#             "I_kernel_inh__X__inh_spikes",
#             "I_kernel_exc__X__exc_spikes",
#             "ATP_kernel_inh__X__inh_spikes"
#         ],
#         "update_expressions": {
#             "ATP": "ATP*__P__ATP__ATP - ATP_h*__P__ATP__ATP + ATP_h + ATP_kernel_exc__X__exc_spikes*__P__ATP__ATP_kernel_exc__X__exc_spikes + ATP_kernel_inh__X__inh_spikes*__P__ATP__ATP_kernel_inh__X__inh_spikes + E_ap*E_ap_tr*__P__ATP__ATP/(K_ATP*homeostatic_s_enabled*o_t*tau_ap) - E_ap*E_ap_tr/(K_ATP*homeostatic_s_enabled*o_t*tau_ap)",
#             "ATP_kernel_exc__X__exc_spikes": "ATP_kernel_exc__X__exc_spikes*__P__ATP_kernel_exc__X__exc_spikes__ATP_kernel_exc__X__exc_spikes",
#             "ATP_kernel_inh__X__inh_spikes": "ATP_kernel_inh__X__inh_spikes*__P__ATP_kernel_inh__X__inh_spikes__ATP_kernel_inh__X__inh_spikes",
#             "I_kernel_exc__X__exc_spikes": "I_kernel_exc__X__exc_spikes*__P__I_kernel_exc__X__exc_spikes__I_kernel_exc__X__exc_spikes",
#             "I_kernel_inh__X__inh_spikes": "I_kernel_inh__X__inh_spikes*__P__I_kernel_inh__X__inh_spikes__I_kernel_inh__X__inh_spikes",
#             "V_abs": "(C_m*(I_kernel_exc__X__exc_spikes*__P__V_abs__I_kernel_exc__X__exc_spikes + I_kernel_inh__X__inh_spikes*__P__V_abs__I_kernel_inh__X__inh_spikes) + __P__V_abs__V_abs*(C_m*V_abs - tau_m*(I_e + I_stim)) + tau_m*(I_e + I_stim))/C_m"
#         }
#     }
# ]
# [30,edlif_percent_mwe, INFO, [24:15;24:15]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [31,edlif_percent_mwe, INFO, [25:15;25:15]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [32,edlif_percent_mwe, INFO, [72:17;72:17]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [33,edlif_percent_mwe, INFO, [77:17;77:17]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [34,edlif_percent_mwe, INFO, [78:16;78:16]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [35,edlif_percent_mwe, INFO, [79:16;79:16]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [36,edlif_percent_mwe, INFO, [80:16;80:16]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [37,edlif_percent_mwe, INFO, [81:21;81:21]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [38,edlif_percent_mwe, INFO, [82:21;82:21]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [39,edlif_percent_mwe, INFO, [84:17;84:17]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [40,edlif_percent_mwe, INFO, [85:17;85:17]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [41,edlif_percent_mwe, INFO, [86:17;86:17]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [42,edlif_percent_mwe, INFO, [114:30;114:30]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [43,edlif_percent_mwe, INFO, [116:30;116:30]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [44,edlif_percent_mwe, INFO, [125:17;125:17]]: Implicit casting from (compatible) type 'integer' to 'real'.
# [45,GLOBAL, INFO]: Rendering template /tmp/nestml-component/edlif_percent_mwe.cpp
# [46,GLOBAL, INFO]: Rendering template /tmp/nestml-component/edlif_percent_mwe.h
# [47,edlif_percent_mwe, INFO, [16:0;153:0]]: Successfully generated code for the model: 'edlif_percent_mwe' in: '/tmp/nestml-component' !
# [48,GLOBAL, INFO]: Rendering template /tmp/nestml-component/CMakeLists.txt
# [49,GLOBAL, INFO]: Rendering template /tmp/nestml-component/nestmlmodule.h
# [50,GLOBAL, INFO]: Rendering template /tmp/nestml-component/nestmlmodule.cpp
# [51,GLOBAL, INFO]: Rendering template /tmp/nestml-component/CMakeLists.txt
# [52,GLOBAL, INFO]: Rendering template /tmp/nestml-component/nestmlmodule.h
# [53,GLOBAL, INFO]: Rendering template /tmp/nestml-component/nestmlmodule.cpp
# [54,GLOBAL, INFO]: Successfully generated NEST module code in '/tmp/nestml-component' !
# -- The CXX compiler identification is GNU 10.3.0
# -- Check for working CXX compiler: /home/wis/anaconda3/envs/wnestml/bin/c++
# -- Check for working CXX compiler: /home/wis/anaconda3/envs/wnestml/bin/c++ -- works
# -- Detecting CXX compiler ABI info
# -- Detecting CXX compiler ABI info - done
# -- Detecting CXX compile features
# -- Detecting CXX compile features - done
#
# -------------------------------------------------------
# nestmlmodule Configuration Summary
# -------------------------------------------------------
#
# C++ compiler         : /home/wis/anaconda3/envs/wnestml/bin/c++
# Build static libs    : OFF
# C++ compiler flags   : -fvisibility-inlines-hidden -std=c++17 -fmessage-length=0 -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/wis/anaconda3/envs/wnestml/include
# NEST compiler flags  : -fvisibility-inlines-hidden -std=c++17 -fmessage-length=0 -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/wis/anaconda3/envs/wnestml/include -fdebug-prefix-map=/home/conda/feedstock_root/build_artifacts/nest-simulator_1648042222842/work=/usr/local/src/conda/nest-simulator-3.3 -fdebug-prefix-map=/home/wis/anaconda3/envs/wnestml=/usr/local/src/conda-prefix -O2 -std=c++11 -Wall -fopenmp -fdiagnostics-color=auto
# NEST include dirs    :  -I/home/wis/anaconda3/envs/wnestml/include/nest -I/home/wis/anaconda3/envs/wnestml/include -I/home/wis/anaconda3/envs/wnestml/include -I/home/wis/anaconda3/envs/wnestml/include -I/home/wis/anaconda3/envs/wnestml/include
# NEST libraries flags : -L/home/wis/anaconda3/envs/wnestml/lib/nest -lnestutil -lnest -lsli -lnestkernel -fopenmp /home/wis/anaconda3/envs/wnestml/lib/libltdl.so /home/wis/anaconda3/envs/wnestml/lib/libreadline.so /home/wis/anaconda3/envs/wnestml/lib/libncurses.so /home/wis/anaconda3/envs/wnestml/lib/libgsl.so /home/wis/anaconda3/envs/wnestml/lib/libgslcblas.so
#
# -------------------------------------------------------
#
# You can now build and install 'nestmlmodule' using
#   make
#   make install
#
# The library file libnestmlmodule.so will be installed to
#   /home/wis/anaconda3/envs/wnestml/lib/nest
# The module can be loaded into NEST using
#   (nestmlmodule) Install       (in SLI)
#   nest.Install(nestmlmodule)   (in PyNEST)
#
# CMake Warning (dev) in CMakeLists.txt:
#   No cmake_minimum_required command is present.  A line of code such as
#
#     cmake_minimum_required(VERSION 3.16)
#
#   should be added at the top of the file.  The version specified may be lower
#   if you wish to support older CMake versions for this project.  For more
#   information run "cmake --help-policy CMP0000".
# This warning is for project developers.  Use -Wno-dev to suppress it.
#
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /tmp/nestml-component
# Scanning dependencies of target nestmlmodule_lib
# [ 16%] Building CXX object CMakeFiles/nestmlmodule_lib.dir/nestmlmodule.o
# [ 33%] Building CXX object CMakeFiles/nestmlmodule_lib.dir/edlif_percent_mwe.o
# /tmp/nestml-component/edlif_percent_mwe.cpp: In constructor 'edlif_percent_mwe::edlif_percent_mwe()':
# /tmp/nestml-component/edlif_percent_mwe.cpp:114:16: warning: unused variable '__resolution' [-Wunused-variable]
#   114 |   const double __resolution = nest::Time::get_resolution().get_ms();  // do not remove, this is necessary for the resolution() function
#       |                ^~~~~~~~~~~~
# [ 50%] Linking CXX shared library libnestmlmodule.so
# [ 50%] Built target nestmlmodule_lib
# Scanning dependencies of target nestmlmodule_module
# [ 66%] Building CXX object CMakeFiles/nestmlmodule_module.dir/nestmlmodule.o
# [ 83%] Building CXX object CMakeFiles/nestmlmodule_module.dir/edlif_percent_mwe.o
# /tmp/nestml-component/edlif_percent_mwe.cpp: In constructor 'edlif_percent_mwe::edlif_percent_mwe()':
# /tmp/nestml-component/edlif_percent_mwe.cpp:114:16: warning: unused variable '__resolution' [-Wunused-variable]
#   114 |   const double __resolution = nest::Time::get_resolution().get_ms();  // do not remove, this is necessary for the resolution() function
#       |                ^~~~~~~~~~~~
# [100%] Linking CXX shared module nestmlmodule.so
# [100%] Built target nestmlmodule_module
# [ 50%] Built target nestmlmodule_lib
# [100%] Built target nestmlmodule_module
# Install the project...
# -- Install configuration: ""
# -- Installing: /home/wis/anaconda3/envs/wnestml/lib/nest/nestmlmodule.so

# %%
nest.Install("nestmlmodule")
# Out:
# Jun 22 11:33:42 Install [Info]:
#     loaded module nestmlmodule

# %%
nest.set_verbosity("M_WARNING")
nest.ResetKernel()

neuron_model_name = neuron_model.split(".")[0]
print(f"Using neuron model: {neuron_model_name}")

#param dict
parameter_dict = {"K_ATP": [1, 1]}
n = 1

# create neurons
pop1 = nest.Create(neuron_model_name, n, params=parameter_dict)
pop2 = nest.Create(neuron_model_name, n, params=parameter_dict)
voltmeter1 = nest.Create("voltmeter")
voltmeter2 = nest.Create("voltmeter")
voltmeter = [voltmeter1, voltmeter2]

# create connections
syn_dict = {#"synapse_model": "stdp_synapse", 
            "weight": 500,
            #"alpha": 1
            }
nest.Connect(pop1, pop2,
             "one_to_one",
             syn_spec=syn_dict)
syn_dict2 = {#"synapse_model": "stdp_synapse", 
            "weight": 2000,
            #"alpha": 1
            }
nest.Connect(pop2, pop1,
             "one_to_one",
             syn_spec=syn_dict2)

voltmeter[0].set({"record_from": ["V_m", "ATP", "ATP_c", "ATP_s", "E_ap_tr", "E_ap_c", "E_syn_c"]}) #, "E_ap_der", "E_ap_tr2"]})
voltmeter[1].set({"record_from": ["V_m", "ATP", "ATP_c", "ATP_s", "E_ap_tr", "E_ap_c", "E_syn_c"]}) #, "E_ap_der", "E_ap_tr2"]})
nest.Connect(voltmeter1, pop1)
nest.Connect(voltmeter2, pop2)

# current generators
dcs = nest.Create('dc_generator')
dcs.set({"amplitude": 376.01})   
dcs.set({"stop": 400})
acs = nest.Create('ac_generator')
acs.set({"amplitude": 150.2})
acs.set({"offset": 250.2})
acs.set({"frequency": 10})
acs.set({"stop": 400})
nest.Connect(dcs, pop1)
nest.Connect(acs, pop2)

# spike recorder
sr = nest.Create("spike_recorder")
nest.Connect(pop1, sr)
nest.Connect(pop2, sr)

nest.Simulate(500.)

# new arrays for reshaped arrays
ts = []
Vms = []
atp = []
atp_h = []
atp_c = []
atp_s = []
e_ap_c = []
e_syn_c = []
st = []

fontsize = 15
fig, ax = plt.subplots(nrows=6, figsize=(15,15))

for idx in range(2):
    # reshape arrays
    print(f"idx: {idx}")
    ts.append(voltmeter[idx].get("events")["times"])
    Vms.append(voltmeter[idx].get("events")["V_m"])
    atp.append(voltmeter[idx].get("events")["ATP"])
    atp_h.append(pop1.get("ATP_h"))
    atp_c.append(voltmeter[idx].get("events")["ATP_c"])
    atp_s.append(voltmeter[idx].get("events")["ATP_s"])
    e_ap_c.append(voltmeter[idx].get("events")["E_ap_c"])
    e_syn_c.append(voltmeter[idx].get("events")["E_syn_c"])
    
    # plot
    ax[0].plot(ts[idx], Vms[idx], label=f"n_{idx}")
    ax[1].plot(ts[idx], atp[idx], label=f"n_{idx}")
    #ax[1].axhline(y=atp_h[idx], ls="--")
    ax[2].plot(ts[idx], atp_c[idx], marker ='.', label=f"n_{idx}")
    #ax[2].axhline(y=pop1.get("ATP_basal"), ls="--")
    ax[3].plot(ts[idx], atp_s[idx], label=f"n_{idx}")
    ax[4].plot(ts[idx], e_ap_c[idx], label=f"n_{idx}")
    ax[5].plot(ts[idx], e_syn_c[idx], label=f"n_{idx}")
    for _ax in ax:
        _ax.grid(True)
        _ax.legend()
    ax[0].set_ylabel("v [mV]", fontsize=fontsize)
    ax[1].set_ylabel("ATP", fontsize=fontsize)
    ax[2].set_ylabel("ATP_c", fontsize=fontsize)
    ax[3].set_ylabel("ATP_s", fontsize=fontsize)
    ax[4].set_ylabel("E_ap_tr", fontsize=fontsize)
    ax[4].set_ylabel("E_ap_c", fontsize=fontsize)
    ax[5].set_ylabel("E_syn_c", fontsize=fontsize)
    ax[-1].set_xlabel("Time [ms]", fontsize=fontsize)
    
    fig.show()
# Out:
# Using neuron model: edlif_percent_mwe
# alpha: -1
# beta: 0
# V_abs: 0 mV
# alpha: -1
# beta: 0.00680228
# V_abs: 0.102034 mV
# alpha: -1
# beta: 0.00688048
# V_abs: 0.103207 mV
# alpha: -1
# beta: 0.0140016
# V_abs: 0.210024 mV
# alpha: -1
# beta: 0.00458152
# V_abs: 0.0687228 mV
# alpha: -1
# beta: 0.018997
# V_abs: 0.284955 mV
# alpha: -1
# beta: 0.0136822
# V_abs: 0.205233 mV
# alpha: -1
# beta: 0.00697216
# V_abs: 0.104582 mV
# alpha: -1
# beta: 0.0234912
# V_abs: 0.352368 mV
# alpha: -1
# beta: 0.0149824
# V_abs: 0.224736 mV
# idx: 0
# idx: 1
# /tmp/ipykernel_16039/1546079589.py:105: UserWarning:Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /tmp/ipykernel_16039/1546079589.py:105: UserWarning:Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
# extracting spikes data
dSD = sr.get("events")
evs = dSD["senders"]
ts = dSD["times"]
plt.plot(ts, evs, ".")
